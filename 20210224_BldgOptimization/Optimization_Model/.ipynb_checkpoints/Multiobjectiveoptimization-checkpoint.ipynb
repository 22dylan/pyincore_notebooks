# %% [markdown]
# #### Multi-Objective Optimiztion Model

# %% [markdown]
# Point of Contact:
#
#  Charles Nicholson - cnicholson@ou.edu
#  Andrés D. González - andres.gonzalez@ou.edu
#
#     Authors:
#         Yunjie Wen
#         Dale Cochran
#         Tarun Adluri
#         Jorge A. Duarte - jduarte@ou.edu
#         Andrés González
#         Version 1.0
# TEAM: OU CORE COMMUNITY RESILLIENCE LAB, UNIVERSITY OF OKLAHOMA

# %%
import pandas as pd
import numpy as np
import csv
import time
import random
import matplotlib.pyplot as plt
from gurobipy import *  
import math
import scipy.interpolate as interp
from mpl_toolkits import mplot3d
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import LineCollection
from matplotlib import animation

# %% [markdown]
# # data Processing

# %% [markdown]
# #### 1. Data Set: Q0 is Calculated from fragility curve. Values of Q_t_hat are based on the Q0.
# #### 2. Strategy cost and building loss estimation is scaled by 1,000,000
# #### 3. r_ijk is calcualted from building ages
# #### 4. recovery time = 2 months after the shock

# %%
#Importing as pandas dataframe, blockgroup information
# pls change data path accordingly
data = pd.read_csv("seaside_qt_data_500.csv")

Sc = pd.read_csv("seaside_sc_data_500.csv")

# %%
# index set
I = Sc["Z"]
J = Sc["S"]
#K = Sc["K"]
#K_p = Sc["K'"]
L=set(zip(Sc["K"],Sc["K'"]))
L = tuplelist(L)

IJ = set(zip(data["Z"],data["S"]))
#IJ = tuplelist(zip(data["Z"],data["S"]))
K = [0,1,2,3]
IJK = tuplelist(zip(data["Z"],data["S"],data["K"] ))
IJKK = tuplelist(zip(Sc["Z"],Sc["S"],Sc["K"],Sc["K'"] ))

# %%
Sc_ijkk={}
for i,j,k,k1 in IJKK:
    Sc_ijkk[i,j,k,k1]=Sc[(Sc["Z"]==i)& (Sc["S"]==j) & (Sc["K"]==k) & (Sc["K'"]==k1)]["Sc"].item()

# %%
b_ijk ={}
for i,j,k in IJK:
    b_ijk[i,j,k]=data[(data["Z"]==i)& (data["S"]==j) & (data["K"]==k)]["b"].item()

# %%
l_ijk ={}
for i,j,k in IJK:
    l_ijk[i,j,k]=data[(data["Z"]==i)& (data["S"]==j) & (data["K"]==k)]["l"].item()

# %%
Q_t_hat = {}
for i,j,k in IJK:
    Q_t_hat[i,j,k]=data[(data["Z"]==i)& (data["S"]==j) & (data["K"]==k)]["Q_t_hat"].item()

# %%
d_ijk = {}
for i,j,k in IJK:
    d_ijk[i,j,k]=data[(data["Z"]==i)& (data["S"]==j) & (data["K"]==k)]["d_ijk"].item()

# %%
def optimal_points(list_loss,list_dislocation,list_func):
    
    """
    This funciton is  to select the optimal points of objective function  from feasible points
    input: 
    list_loss: list of economic values 
    list_dislocation: list of population dislocation values
    list_func: list of functionality values
    return:
    loss_optimal: list of optimal values of economic loss
    dislocation_optimal:list of optimal values of population dislocatio
    func_optimal:list of optimal values of funcitonality
    
    """ 
    
    l_com = []
    for i in range(0,len(list_loss)):
        l_com.append(tuple([list_loss[i],list_dislocation[i],list_func[i]]))
    # remove the repeated the points
    set_com = set(l_com)
    
    # change the set to list
    list_temp = []
    for x in set_com:
        list_temp.append(x)
    #print("new order:")
    #print(list_temp)
    # if loss and dislocation values  are same as the last loop, find the best value for functionality
    final_f = []
    f_temp = []
    for i in range(len(list_temp)): 
        for j in range(i+1,len(list_temp)):
            if list_temp[i][0] == list_temp[j][0] and list_temp[i][1] ==  list_temp[j][1]:
                if list_temp[i][2] > list_temp[j][2]:
                    f_temp.append(list_temp[i])
                    
                elif list_temp[j][2] > list_temp[i][2]:
                    f_temp.append(list_temp[j])
    final_f = list(set(list_temp) - set(f_temp))
    #print("functionality")
    #print(final_f)
    
    # find the optimal value for dislocation if loss and functionality are same as the last loop
    final_d = []  
    d_temp = []
    for i in range(len(final_f)):
        for j in range(i+1,len(final_f)):
            if final_f[i][0] == final_f[j][0] and final_f[i][2] ==  final_f[j][2]:
                if final_f[i][1] < final_f[j][1]:
                    d_temp.append(final_f[j])
                elif final_f[i][1] > final_f[j][1]:
                    d_temp.append(final_f[i]) 
          
    final_d = list(set(final_f) - set(d_temp))
    #print('dislocation')
    #print(final_d)
    
    # find the optimal value for loss if dislocation and functionality are same as the last loop
    final_l = []
    l_temp = []
    for i in range(len(final_d)):
        for j in range(i+1,len(final_d)):
            if final_d[i][1] == final_d[j][1] and final_d[i][2] ==  final_d[j][2]:
                if final_d[i][0] < final_d[j][0]:
                    l_temp.append(final_d[j])
                elif final_d[i][0] > final_d[j][0]:
                    l_temp.append(final_d[i]) 
    final_l = list(set(final_d) - set(l_temp))
    
    #print('loss')
    #print(final_l)        
    loss_optimal = []
    dislocation_optimal = []
    func_optimal = []
    for x in final_l:
        loss_optimal.append(x[0])
        dislocation_optimal.append(x[1])
        func_optimal.append(x[2])
        
    return loss_optimal,dislocation_optimal,func_optimal

# %%
def obj_dislocation(B):
    """
    This function optimizes Population Dislocation
    In this function, direct economic loss objective and buiding functionality  objective are relax 
    in order to find the maximum epsilon and minimum epsilon for population dislocation
    
    Input: B: retrofit budget
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3

    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    #for i, j, k in IJK:
        #x[i, j, k] = mod.addVar(name='#Building_%s_%s_%s' % (i, j, k),lb =0.0, obj=0, vtype = GRB.CONTINUOUS) 
    #for i,j,k,k1 in IJKK:
        #y[i, j, k,k1] = mod.addVar(name='#Building_%s_%s_%s_%s' % (i, j, k,k1),lb =0.0, obj=0, vtype = GRB.CONTINUOUS)
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Dislocation, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")

        tot_dislocation = mod.objval
        tot_functionality = Functionality.X
        tot_eco_loss = Eco_loss.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
        
        #print("all variabels:",mod.getVars())
        #print("Total population dislocation:",tot_dislocation )
        #print("Total economic loss:",tot_eco_loss)
        #print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        mod.computeIIS()
        mod.write("Results/model.ilp")
        mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def obj_ecoloss(B):
    """
    This function optimize direct economic loss 
    In this function, population dislocation objective and buiding functionality objective are relax 
    in order to find the maximum epsilon and minimum epsilon for direct economic loss
    
    Input: B: retrofit budget
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum (l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Eco_loss, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")

        tot_eco_loss = mod.objval
        tot_dislocation = Dislocation.X
        tot_functionality = Functionality.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
        
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        mod.computeIIS()
        mod.write("Results/model.ilp")
        mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def obj_functionality(B):
    """
    This function optimize direct building functionality 
    In this function, direct economic loss objective and population dislocation objective are relax 
    in order to find the maximum epsilon and minimum epsilon for building functionality
    
    Input: B: retrofit budget
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Functionality, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")

        tot_functionality = mod.objval
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
        tot_dislocation = Dislocation.X
        tot_eco_loss = Eco_loss.X
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        mod.computeIIS()
        mod.write("Results/model.ilp")
        mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_dislocation_optimize_eco(B,epsilon_dislocation):
    """
    This function optimizes the total economic loss with constraints on dislocation
    input:
    B: budget constrains
    epsilon_dislocation: constraint bound for total dislocation
     
    """ 
     # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr (Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(2):Population dislocation
    mod.addConstr (Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr (Dislocation <= epsilon_dislocation)
    
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Eco_loss, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        
        tot_eco_loss = mod.objval
        tot_functionality = Functionality.X
        tot_dislocation = Dislocation.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
        
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        
        # write results to CSV file
        
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_eco_optimize_dislocation(B,epsilon_eco):
    """
    This function optimizes population disloation with constraints on economic loss
    input:
    B: budget constrains
    epsilon_eco: constraint bound for total economic loss
     
    """ 
     # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Eco_loss <= epsilon_eco) 
    
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Dislocation, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        
        tot_dislocation = mod.objval
        tot_eco_loss = Eco_loss.X
        tot_functionality = Functionality.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_eco_optimize_functionality(B,epsilon_eco):
    """
    This function optimizes the total functionality with constraints on economis loss
    input:
    B: budget constrains
    epsilon_eco: constraint bound for total economic loss
     
    """ 
     # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Eco_loss <= epsilon_eco) 
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Functionality, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_functionality = mod.objval
        tot_dislocation = Dislocation.X
        tot_eco_loss = Eco_loss.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_dislocation_opitimize_functionality(B,epsilon_dislocation):
    """
    This function optimizes the total functionality with constraints on total dislocation
    input:
    B: budget constrains
    epsilon_dislocation: constraint bound for dislocation
    
    """ 
     # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
     
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Dislocation <= epsilon_dislocation) 
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Functionality, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_functionality = mod.objval
        tot_dislocation = Dislocation.X
        tot_eco_loss = Eco_loss.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_functionality_optimize_dislocation(B,epsilon_func):
    """
    This function optimizes the total dislocation with constraints on total functionality
    input:
    B: budget constrains
    epsilon_func: constraint bound for total functionality
    
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
     
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Functionality <= epsilon_func)
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Dislocation, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_eco_loss = Eco_loss.X
        tot_functionality = Functionality.X
        tot_dislocation = mod.objval
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_functionality_optimize_eco(B,epsilon_func):
    """
    This function optimizes the total economic loss with constraints on total functionality
    input:
    B: budget constrains
    epsilon_func: constraint bound for total funcitonality
    
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
     
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Functionality <= epsilon_func)
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Eco_loss, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_eco_loss = mod.objval
        tot_functionality = Functionality.X
        tot_dislocation = Dislocation.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_dislocation_func(B,epsilon_dislocation,epsilon_func):
    """
    This function optimizes the total economic loss with constraints on dislocation and functionality
    input:
    B: budget constrains
    epsilon_dislocation: constraint bound for total dislocation
    epsilon_func: constraint bound for total functionality
    return: 
    total economic loss while total dislocation value is equal to epsilon_eco and 
    functionality is equal to epsilon_func
    
    """ 
     # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
     
    # epsilon constraint(2):Population dislocation
    mod.addConstr(Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Dislocation <= epsilon_dislocation)
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(-Functionality <= -epsilon_func)
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Eco_loss, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_eco_loss = mod.objval
        tot_functionality = Functionality.X
        tot_dislocation = Dislocation.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_ecoloss_functionality(B,epsilon_eco,epsilon_func):
    """
    This function optimize the total dislocation with constraints on total economic loss and funcionality
    input:
    budget_input: budget constrains
    epsilon_eco: constraint bound for total economic loss
    epsilon_func: constraint bound for total functionality
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-3
    mod.params.NumericFocus = 0
    mod.params.FeasibilityTol = 1e-3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr(Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(Eco_loss <= epsilon_eco) 
    # epsilon constraint(2):Population dislocation
    mod.addConstr (Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    #mod.addConstr(Dislocation < epsilon_dislocation)
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr(-Functionality <= -epsilon_func)
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Dislocation, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_dislocation = mod.objval
        tot_eco_loss = Eco_loss.X
        tot_functionality = Functionality.X
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

#     except:
#         print("Gurobi error", mod.status)
#         return - 1, -1, -1,-1,-1

# %%
def epsilon_ecoloss_dislocation(B,epsilon_eco,epsilon_dislocation):
    """
    This function optimizes the total functionality with constraints on total economic loss and location
    input:
    B: budget constrains
    epsilon_eco: constraint bound for total economic loss
    epsilon_dislocation: constraint bound for total dislocation
    """ 
    # Gurobi model set
    mod = Model('Dislocation Optimization Model_Joplin')
    mod.setParam('OutputFlag', 0)
    mod.setParam('LogToConsole', 0)
    mod.setParam('LogFile', "")
    mod.params.threads = 1
    mod.params.NodefileStart = 1
    mod.params.OptimalityTol = 1e-6
    mod.params.NumericFocus = 3
    
    ################################ Decision Variables ###################################
    x=mod.addVars(IJK,name="x")
    y=mod.addVars(IJKK,name="y")
    
    ################################ Epsilon Constraints variables#########################
    # optimization variable: Total population dislocation
    Dislocation = mod.addVar(name='Total_dislocation', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total economic loss
    Eco_loss = mod.addVar(name='Total_Economic_Loss', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # optimization variable: Total_housing_functionality
    Functionality = mod.addVar(name='Total_housing_functionality', obj=0,lb=-GRB.INFINITY, vtype = GRB.CONTINUOUS)
    
    # Process any pending model modifications.
    mod.update()
    ################################Constraints############################
    # Budget constraint
    mod.addConstr(quicksum( Sc_ijkk[i,j,k,k_p] * y[i, j,k,k_p] for i, j,k,k_p in IJKK) <= B)
    # retrofit before and after constraint
    mod.addConstrs((sum(x[i,j,k] for k in K)== sum(b_ijk[i,j,k] for k in K) for i,j in IJ))
    #Constraint: Retrfitting strategy from k to k'
    mod.addConstrs((x[i,j,k]  == (sum(y[i,j,k_p,k] for k_p,k in L.select('*',k))) + b_ijk[i,j,k]
               - sum(y[i,j,k,k_p] for k,k_p in L.select(k, '*'))for i,j,k in IJK)) 
    
    #############################Epsilon Constraints#######################
    # epsilon constraint(1): Direct economic loss
    mod.addConstr (Eco_loss == quicksum ( l_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr (Eco_loss <= epsilon_eco) 
    # epsilon constraint(2):Population dislocation
    mod.addConstr (Dislocation == quicksum ( d_ijk[i, j, k] * x[i, j, k] for i, j, k in IJK))
    mod.addConstr (Dislocation <= epsilon_dislocation)
    # epsilon constraint(3): housing functionality bound
    mod.addConstr(Functionality == quicksum ( Q_t_hat[i, j, k] * x[i, j, k] for i, j, k in IJK))
    #mod.addConstr(Functionality > epsilon_func)
    ##############################Objective###############################
    # objective: Equation (10) Optimizing total dislocation
    mod.setObjective(Functionality, GRB.MINIMIZE)
    
    mod.update()
    mod.optimize()

    # OPTIMAL 	2 	Model was solved to optimality (subject to tolerances), and an optimal solution is available
    # INFEASIBLE 	3 	Model was proven to be infeasible.
    # TIME_LIMIT 	9 	Optimization terminated because the time expended exceeded the value specified
    #                   in the TimeLimit parameter.
    if mod.status == 2 or mod.status == 9:
        # The objective value for the current solution.
        # If the model was solved to optimality, then this attribute gives the optimal objective value.

        # To print lp model in readable way
        # mod.write("Results/model.lp")
        tot_dislocation = Dislocation.X
        tot_eco_loss = Eco_loss.X
        tot_functionality = mod.objval
        strategy_x = mod.getAttr('x', x)
        strategy_y = mod.getAttr('x', y)
    
        #print("all variabels:",mod.getVars())
        print("Total population dislocation:",tot_dislocation )
        print("Total economic loss:",tot_eco_loss)
        print ("Total housing funcnationality:",tot_functionality)
        
        return tot_eco_loss, tot_dislocation, strategy_x, tot_functionality, strategy_y

    else:

        #mod.write("Results/model.lp")
        #
        # # If model is infeasible, print possible constraint that cause it
        #mod.computeIIS()
        #mod.write("Results/model.ilp")
        #mod.write("Results/model.mps")

        print ("Gurobi status is", mod.status)
        return - 1, -1, -1,-1,-1

      #except:
        #print("Gurobi error", mod.status)
#       return - 1, -1, -1,-1,-1

# %%
# set up baseline scenario
# max_budget = quicksum(Sc_ijkk[i,j,0,3] * b_ijk[i, j,k] for i,j,k in IJK).getValue()
# max_budget

# %%
max_budget=200000000
max_budget
# Out:
# 200000000

# %%
print("20%",max_budget*0.20)
print("40%",max_budget*0.40)
print("60%",max_budget*0.60)
# Out:
# 20% 40000000.0
# 40% 80000000.0
# 60% 120000000.0

# %%
# total asset in Joplin: 2,017,732,030
# Maximum loss without any intervention
Max_eco_loss = quicksum( l_ijk[i,j,k] * b_ijk[i, j,k] for i, j,k in IJK).getValue()
Max_eco_loss
# Out:
# 234244445.19340885

# %%
# Maximum total dislocation
max_dislocation = quicksum(d_ijk[i,j,k] * b_ijk[i,j,k] for i, j,k in IJK).getValue()
max_dislocation
# Out:
# 2574.8336171936253

# %%
# total number of buildings before mitigation effors
B_ijk = sum(b_ijk[i,j,k] for i,j,k in IJK)
B_ijk
# Out:
# 4453

# %% [markdown]
# #### Find the feasible region for the problem.

# %%
# find boundary for each objective function
def feasible_region(maximum_budget, p):
    """
    input: 
    max_budget: maximum budget for the retrofitting
    p: percentage of max_budget\
    
    return: 
    """
    eco_loss = [None]*2
    dislocation = [None]*2
    functionality = [None]*2
    
    loss1, dislocation1, _,f1,_ = obj_ecoloss(max_budget*p)
    loss2, dislocation2, _,f2,_ = obj_dislocation(max_budget*p)
    loss3, dislocation3, _,f3,_ = obj_functionality(max_budget*p)
    
    max_dislocation= max(dislocation1,dislocation2,dislocation3)
    min_dislocation= min(dislocation1,dislocation2,dislocation3)
    dislocation[0] = max_dislocation
    dislocation[1] = min_dislocation
    
    max_loss = max(loss1,loss2,loss3)
    min_loss = min(loss1,loss2,loss3)
    eco_loss[0] = max_loss
    eco_loss[1] = min_loss
    
    max_f = max(f1,f2,f3)
    min_f = min(f1,f2,f3)
    functionality [0] = max_f
    functionality [1] = min_f
    
    return eco_loss,dislocation,functionality

# %%
def epsilon_steps(L, D, F, p):
    
    L_step = (L[0] - L[1])* p
    F_step = (F[0]-F[1] )* p
    D_step = (D[0] - D[1])* p
     
    return L_step,D_step,F_step

# %% [markdown]
# ### Optimization: Three competing objetives
# ### Epsilon constriants on dislocation and functionality, optimize direct economic loss

# %%
# epsilon steps
eco_range2, dislocation_range2,func_range2 = feasible_region(max_budget, 0.2)
eco_step2, dislocation_step2, func_step2 = \
            epsilon_steps(eco_range2, dislocation_range2, func_range2, 0.1)
# Out:
# Total population dislocation: 2534.197178939206
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.39910181503262
# Total population dislocation: 2554.4242891051126
# Total economic loss: 233508735.41300222
# Total housing funcnationality: 123.132634372324

# %%
# book keeping
listLoss_dfe = []
listStrategy_x = []
listStrategy_y = []
listDislocation_dfe = []
listDislocationBlockgroup_dfe = []
listHousingFunctionality_dfe = []
epsilon_dis = []
epsilon_func = []
# epsilon steps
eco_range2, dislocation_range2,func_range2 = feasible_region(max_budget, 0.2)
eco_step2, dislocation_step2, func_step2 = \
            epsilon_steps(eco_range2, dislocation_range2, func_range2, 0.1)
# optimization: add epsilon constraint on dislocation and  total_housing_functionality, opitimize total_direct_loss, 
counter = 0
best_eco = eco_range2[0]
for dislocation_bound in np.arange(dislocation_range2[1], dislocation_range2[0],dislocation_step2):
    print ("--------iteration step", counter,"--------------")
    print("+++++++++++++++++++++dislocation bound++++++++++++",dislocation_bound)
    best_eco = eco_range2[0]
    for func_bound in np.arange(func_range2[0], func_range2[1], -func_step2):
        print("+++++++++++++++++++++functionality bound++++++++++++",func_bound)
    
        total_direct_loss, total_dislocation, strategy_x,func, strategy_y = \
                        epsilon_dislocation_func(max_budget*0.2,dislocation_bound,func_bound)
        
        if total_direct_loss != -1:
            if total_direct_loss <= best_eco:
                best_eco = total_direct_loss
                epsilon_dis.append(dislocation_bound)
                epsilon_func.append(func_bound)

                listStrategy_x.append(strategy_x)
                listLoss_dfe.append(best_eco)
                listDislocation_dfe.append(total_dislocation)
                listStrategy_y.append(strategy_y)
                listHousingFunctionality_dfe.append(func)
    
    counter += 1
df_optimal_dfe = pd.DataFrame({"Dislocation_bound":epsilon_dis,
                               "Functionality_bound": epsilon_func,
                               "Economic_loss":listLoss_dfe,
                               "Dislocation":listDislocation_dfe, 
                               "Functionality":listHousingFunctionality_dfe})
print("---------------------Overview Result-------------------")
print(df_optimal_dfe)
#Optimal solutions to CSV
# Optimal results
df_optimal_dfe = pd.DataFrame({"Economic_loss":listLoss_dfe,"Dislocation":listDislocation_dfe, "Functionality":listHousingFunctionality_dfe})
df_optimal_dfe.to_csv('Results/results_B20_.csv',index = False)
# Decision variable
# Decision variable:X
for i in range(len(listStrategy_x)):
    x_i = listStrategy_x[i]
    pd_i = pd.DataFrame(list(listStrategy_x[i].iteritems()),  columns = ['Keys','Values'] )
    pd_i[['Z','S','K']] = pd.DataFrame(pd_i['Keys'].values.tolist(), columns = ['Z','S','K'])
    pd_i.to_csv("Results/decision_variable_B20_X{}.csv".format(i))
# Decision variable:Y
for i in range(len(listStrategy_y)):
    y_i = listStrategy_y[i]
    pd_i = pd.DataFrame(list(listStrategy_y[i].iteritems()),  columns = ['Keys','Values'] )
    pd_i[["Z","S","K","K'"]] = pd.DataFrame(pd_i['Keys'].values.tolist(), columns = ["Z","S","K","K'"])
    pd_i.to_csv("Results/decision_variable_B20_Y{}.csv".format(i))
# Out:
# Total population dislocation: 2534.197178939206
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.39910181503262
# Total population dislocation: 2554.4242891051126
# Total economic loss: 233508735.41300222
# Total housing funcnationality: 123.132634372324
# --------iteration step 0 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2295.6498391340165
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Gurobi status is 4
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Gurobi status is 4
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Gurobi status is 4
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2295.6498391340165
# Total economic loss: 216615224.68182486
# Total housing funcnationality: 179.7754086387094
# --------iteration step 1 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2321.527284131126
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Gurobi status is 4
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2321.527284131126
# Total economic loss: 215025731.08723766
# Total housing funcnationality: 189.97245507076175
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2321.527284131126
# Total economic loss: 211567143.3068496
# Total housing funcnationality: 182.54580832649089
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.66937032
# Total housing funcnationality: 177.2022006879479
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.66937038
# Total housing funcnationality: 177.10588299529783
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.6693704
# Total housing funcnationality: 177.11710938962142
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.66937032
# Total housing funcnationality: 177.2022006879479
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.66937032
# Total housing funcnationality: 177.2022006879479
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.66937038
# Total housing funcnationality: 177.181531990571
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2321.527284131126
# Total economic loss: 211126783.66937032
# Total housing funcnationality: 177.2022006879479
# --------iteration step 2 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2347.404729128236
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Gurobi status is 4
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2347.404729128236
# Total economic loss: 209908625.50223082
# Total housing funcnationality: 189.97245507076175
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2347.404729128236
# Total economic loss: 208416847.37577772
# Total housing funcnationality: 182.54580832649089
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2347.404729128236
# Total economic loss: 208283125.60331678
# Total housing funcnationality: 180.13561142947083
# --------iteration step 3 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2373.2821741253456
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2373.2821741253456
# Total economic loss: 210238243.2468334
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2373.2821741253456
# Total economic loss: 207268276.4802464
# Total housing funcnationality: 189.97245507076175
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186693
# Total housing funcnationality: 183.20163913211056
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186696
# Total housing funcnationality: 183.22595232436228
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186696
# Total housing funcnationality: 183.22595232436228
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186693
# Total housing funcnationality: 183.20163913211056
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186696
# Total housing funcnationality: 183.22595232436228
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186693
# Total housing funcnationality: 183.20163913211056
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186696
# Total housing funcnationality: 183.22595232436228
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2373.2821741253456
# Total economic loss: 206724805.76186696
# Total housing funcnationality: 183.22595232436228
# --------iteration step 4 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2399.1596191224553
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2399.1596191224553
# Total economic loss: 207279474.66363236
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205666243.63319224
# Total housing funcnationality: 189.97245507076175
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.68951032
# Total housing funcnationality: 186.2769423444694
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.6895103
# Total housing funcnationality: 186.27694234446938
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.6895103
# Total housing funcnationality: 186.27694234446938
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.68951032
# Total housing funcnationality: 186.2769423444694
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.6895103
# Total housing funcnationality: 186.27694234446938
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.68951032
# Total housing funcnationality: 186.2769423444694
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.6895103
# Total housing funcnationality: 186.27694234446938
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2399.1596191224553
# Total economic loss: 205512472.6895103
# Total housing funcnationality: 186.27666503813856
# --------iteration step 5 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2425.037064119565
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2425.037064119565
# Total economic loss: 205639972.9366826
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2425.037064119565
# Total economic loss: 204747671.17665058
# Total housing funcnationality: 189.97245507076175
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2425.037064119565
# Total economic loss: 204734014.1483186
# Total housing funcnationality: 188.6075716728645
# --------iteration step 6 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2450.9145091166747
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204700050.85185102
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7438355595727
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7438355595727
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7438355595727
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7438355595727
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7679611508905
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7679611508905
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7679611508905
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7438355595727
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2450.9145091166747
# Total economic loss: 204247800.01065257
# Total housing funcnationality: 190.7679611508905
# --------iteration step 7 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2476.7919541137844
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2476.7919541137844
# Total economic loss: 204123493.03575474
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2476.7919541137844
# Total economic loss: 203954942.44915923
# Total housing funcnationality: 193.23622667142297
# --------iteration step 8 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2502.669399110894
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2502.669399110894
# Total economic loss: 203864139.26735502
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2502.669399110894
# Total economic loss: 203810149.88172954
# Total housing funcnationality: 195.13246997196595
# --------iteration step 9 --------------
# +++++++++++++++++++++dislocation bound++++++++++++ 2528.546844108004
# +++++++++++++++++++++functionality bound++++++++++++ 197.39910181503262
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792011.42604828
# Total housing funcnationality: 197.39910181503262
# +++++++++++++++++++++functionality bound++++++++++++ 189.97245507076175
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.0519932
# Total housing funcnationality: 197.26285362340846
# +++++++++++++++++++++functionality bound++++++++++++ 182.54580832649089
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.05199316
# Total housing funcnationality: 197.3018971159675
# +++++++++++++++++++++functionality bound++++++++++++ 175.11916158222002
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.0519932
# Total housing funcnationality: 197.11982280093594
# +++++++++++++++++++++functionality bound++++++++++++ 167.69251483794915
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.05199307
# Total housing funcnationality: 197.30840962716607
# +++++++++++++++++++++functionality bound++++++++++++ 160.26586809367828
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.05199313
# Total housing funcnationality: 197.0845236757683
# +++++++++++++++++++++functionality bound++++++++++++ 152.8392213494074
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.0519932
# Total housing funcnationality: 197.1230408777588
# +++++++++++++++++++++functionality bound++++++++++++ 145.41257460513654
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.05199322
# Total housing funcnationality: 197.11674143074126
# +++++++++++++++++++++functionality bound++++++++++++ 137.98592786086567
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.05199313
# Total housing funcnationality: 197.1697966479888
# +++++++++++++++++++++functionality bound++++++++++++ 130.5592811165948
# Total population dislocation: 2528.546844108004
# Total economic loss: 203792010.05199316
# Total housing funcnationality: 197.12488688743267
# ---------------------Overview Result-------------------
#     Dislocation_bound  Functionality_bound  Economic_loss  Dislocation  \
# 0         2295.649839           175.119162   2.166152e+08  2295.649839
# 1         2295.649839           167.692515   2.166152e+08  2295.649839
# 2         2295.649839           160.265868   2.166152e+08  2295.649839
# 3         2295.649839           152.839221   2.166152e+08  2295.649839
# 4         2295.649839           145.412575   2.166152e+08  2295.649839
# ..                ...                  ...            ...          ...
# 74        2502.669399           130.559281   2.038101e+08  2502.669399
# 75        2528.546844           197.399102   2.037920e+08  2528.546844
# 76        2528.546844           189.972455   2.037920e+08  2528.546844
# 77        2528.546844           182.545808   2.037920e+08  2528.546844
# 78        2528.546844           167.692515   2.037920e+08  2528.546844
#
#     Functionality
# 0      179.775409
# 1      179.775409
# 2      179.775409
# 3      179.775409
# 4      179.775409
# ..            ...
# 74     195.132470
# 75     197.399102
# 76     197.262854
# 77     197.301897
# 78     197.308410
#
# [79 rows x 5 columns]

# %% [markdown]
# ### Optimization 2
# ### Three competing objectives
# ### epsilon constraints on direct economic loss and functionality, optimize dislocation

# %%
# Optimization 2 ###############
# book keeping
listLoss_fed20 = []
listStrategy_fed20_x = []
listDislocation_fed20 = []
listDislocationBlockgroup_fed20 = []
listHousingFunctionality_fed20 = []
listStrategy_fed20_y=[]
epsilon_func = []
epsilon_eco  = []  

# epsilon steps
eco_range2, dislocation_range2,func_range2 = feasible_region(max_budget, 0.2)
eco_step2, dislocation_step2, func_step2 = \
            epsilon_steps(eco_range2, dislocation_range2, func_range2, 0.05)
counter = 0
best_dislocation = dislocation_range2[0]
for  func_bound in np.arange(func_range2[1], func_range2[0],func_step2): 
    print ("--------iteration step", counter,"--------------")
    print("+++++++++++functionality bound", func_bound,"++++++++++")      
    
     
    for eco_bound in np.arange(eco_range2[1], eco_range2[0], eco_step2):
        print("+++++++++++economic bound", eco_bound,"++++++++++")
        total_direct_loss, total_dislocation, strategy_x,func,strategy_y = \
                    epsilon_ecoloss_functionality(max_budget*0.2,eco_bound,func_bound)
        
        if total_dislocation !=-1:   
            
            epsilon_func.append(func_bound)
            epsilon_eco.append(eco_bound)
            listLoss_fed20.append(total_direct_loss)
            listDislocation_fed20.append(total_dislocation)
            listHousingFunctionality_fed20.append(func)
            listStrategy_fed20_x.append(strategy_x)
            listStrategy_fed20_y.append(strategy_y)
        else:
            print("Infeasible")
    counter += 1
loss_optimal20, dislocation_optimal20,func_optimal20 = optimal_points(listLoss_fed20,listDislocation_fed20,listHousingFunctionality_fed20)
df_fed20 = pd.DataFrame({"Economic_bound":epsilon_eco,
                               "Functionality_bound": epsilon_func,
                               "Economic_loss":listLoss_fed20,
                               "Dislocation":listDislocation_fed20, 
                               "Functionality":listHousingFunctionality_fed20})
print("---------------------Overview Result-------------------")
print(df_fed20)
df_fed20_optimal = pd.DataFrame({
                               "Economic_loss":loss_optimal20,
                               "Dislocation":dislocation_optimal20, 
                               "Functionality":func_optimal20})
print("---------------------Overview Optimal Result-------------------")
print(df_fed20_optimal)

df_fed20_optimal = pd.DataFrame({"Economic_loss":listLoss_fed20,"Dislocation":listDislocation_fed20, "Functionality":listHousingFunctionality_fed20})
df_fed20_optimal.to_csv('Results/results_B20_.csv',index = False)
# Decision variable
# Decision variable:X
for i in range(len(listStrategy_fed20_x)):
    x_i = listStrategy_fed20_x[i]
    pd_i = pd.DataFrame(list(listStrategy_fed20_x[i].iteritems()),  columns = ['Keys','Values'] )
    pd_i[['Z','S','K']] = pd.DataFrame(pd_i['Keys'].values.tolist(), columns = ['Z','S','K'])
    pd_i.to_csv("Results/decision_variable_B20_X{}.csv".format(i))
# Out:
# Total population dislocation: 2534.197178939206
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.39910181503262
# Total population dislocation: 2554.4242891051126
# Total economic loss: 233508735.41300222
# Total housing funcnationality: 123.132634372324
# --------iteration step 0 --------------
# +++++++++++functionality bound 123.132634372324 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 1 --------------
# +++++++++++functionality bound 126.84595774445944 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 2 --------------
# +++++++++++functionality bound 130.5592811165949 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 3 --------------
# +++++++++++functionality bound 134.2726044887303 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 4 --------------
# +++++++++++functionality bound 137.98592786086573 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 5 --------------
# +++++++++++functionality bound 141.69925123300118 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 6 --------------
# +++++++++++functionality bound 145.41257460513663 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 7 --------------
# +++++++++++functionality bound 149.12589797727205 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 8 --------------
# +++++++++++functionality bound 152.83922134940747 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 9 --------------
# +++++++++++functionality bound 156.55254472154292 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7092541274837
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94131390810463
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5729349294
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.4881602157316
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8919817024816
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.17484423375294
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1161080041625
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.18570476992022
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.956989201018
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.31345000269727
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3756296315596
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.42453675292114
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.4958053315167
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.17249142618388
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4881964924584
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43904703604403
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.2617526485665
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.41886078402155
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 10 --------------
# +++++++++++functionality bound 160.26586809367836 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7095471429134
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.9171548208154
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5727170746186
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.41731630829247
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8909121211445
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.20130778748825
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.1182510448816
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.2333246951841
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.954683922175
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.37796946488606
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.3799598106616
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.26867501308837
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.502274072297
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 177.5541578688141
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.488140396751
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.43298923745112
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.264255083661
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.42293097132364
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 11 --------------
# +++++++++++functionality bound 163.97919146581378 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7083563660008
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.9175231968937
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2372.5716997992095
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 184.58335634538386
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2347.8909121211445
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 180.20130778748825
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2331.115943696197
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 177.196723206322
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2320.9544550572514
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 177.49472572065852
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2312.381360792155
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 177.72452741218052
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2304.51265325845
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 176.81796469317683
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2297.4875303874273
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 179.4487275966056
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2296.260829987569
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 180.4371720274374
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2295.6500950401683
# Total economic loss: 216614004.631429
# Total housing funcnationality: 179.7654600072206
# --------iteration step 12 --------------
# +++++++++++functionality bound 167.6925148379492 ++++++++++
# ...
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2297.8604729640715
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2297.846208937951
# Total economic loss: 217079811.96515664
# Total housing funcnationality: 182.54580832649094
# --------iteration step 17 --------------
# +++++++++++functionality bound 186.2591316986264 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2405.7095983887466
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 186.94318695186513
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2373.5269289927305
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2354.4972006457465
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2340.5673765680867
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2329.4603421036422
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2320.8259559006624
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2313.8193942240873
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2308.563474066391
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2305.5997583801845
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2305.287277976778
# Total economic loss: 217622271.5128336
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2305.2870253139954
# Total economic loss: 217639540.74833477
# Total housing funcnationality: 186.2591316986264
# --------iteration step 18 --------------
# +++++++++++functionality bound 189.97245507076184 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2408.0324650844145
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2380.0836616688885
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2362.063329054313
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2348.7347113506535
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2338.6397137153517
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2330.863873512036
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2324.3018359292423
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2319.706392405186
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2318.08142259895
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2317.800463613452
# Total economic loss: 218650372.73249805
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2317.7078429379094
# Total economic loss: 218320448.41723263
# Total housing funcnationality: 189.97245507076184
# --------iteration step 19 --------------
# +++++++++++functionality bound 193.68577844289726 ++++++++++
# +++++++++++economic bound 203792010.05199403 ++++++++++
# Total population dislocation: 2527.9246800480128
# Total economic loss: 203792010.05199403
# Total housing funcnationality: 197.23064142667164
# +++++++++++economic bound 205277846.32004443 ++++++++++
# Total population dislocation: 2417.6304261065166
# Total economic loss: 205277846.32004443
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 206763682.58809483 ++++++++++
# Total population dislocation: 2390.5684936853504
# Total economic loss: 206763682.58809483
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 208249518.85614523 ++++++++++
# Total population dislocation: 2373.2460867989885
# Total economic loss: 208249518.85614523
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 209735355.12419564 ++++++++++
# Total population dislocation: 2360.520019240613
# Total economic loss: 209735355.12419564
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 211221191.39224604 ++++++++++
# Total population dislocation: 2351.167737746747
# Total economic loss: 211221191.39224604
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 212707027.66029644 ++++++++++
# Total population dislocation: 2343.9778843275976
# Total economic loss: 212707027.66029644
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 214192863.92834684 ++++++++++
# Total population dislocation: 2338.529289933206
# Total economic loss: 214192863.92834684
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 215678700.19639724 ++++++++++
# Total population dislocation: 2335.663506214545
# Total economic loss: 215678700.19639724
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 217164536.46444765 ++++++++++
# Total population dislocation: 2334.0196726086947
# Total economic loss: 217164536.46444765
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 218650372.73249805 ++++++++++
# Total population dislocation: 2334.1374902586253
# Total economic loss: 218650372.73249805
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 220136209.00054845 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 221622045.26859885 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 223107881.53664926 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 224593717.80469966 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 226079554.07275006 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 227565390.34080046 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 229051226.60885087 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 230537062.87690127 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# +++++++++++economic bound 232022899.14495167 ++++++++++
# Total population dislocation: 2333.942947709855
# Total economic loss: 217474328.91269583
# Total housing funcnationality: 193.68577844289726
# ---------------------Overview Result-------------------
#      Economic_bound  Functionality_bound  Economic_loss  Dislocation  \
# 0      2.037920e+08           123.132634   2.037920e+08  2527.924680
# 1      2.052778e+08           123.132634   2.052778e+08  2405.709254
# 2      2.067637e+08           123.132634   2.067637e+08  2372.572935
# 3      2.082495e+08           123.132634   2.082495e+08  2347.891982
# 4      2.097354e+08           123.132634   2.097354e+08  2331.116108
# ..              ...                  ...            ...          ...
# 395    2.260796e+08           193.685778   2.174743e+08  2333.942948
# 396    2.275654e+08           193.685778   2.174743e+08  2333.942948
# 397    2.290512e+08           193.685778   2.174743e+08  2333.942948
# 398    2.305371e+08           193.685778   2.174743e+08  2333.942948
# 399    2.320229e+08           193.685778   2.174743e+08  2333.942948
#
#      Functionality
# 0       197.230641
# 1       186.941314
# 2       184.488160
# 3       180.174844
# 4       177.185705
# ..             ...
# 395     193.685778
# 396     193.685778
# 397     193.685778
# 398     193.685778
# 399     193.685778
#
# [400 rows x 5 columns]
# ---------------------Overview Optimal Result-------------------
#      Economic_loss  Dislocation  Functionality
# 0     2.097354e+08  2334.615418     182.545808
# 1     2.171645e+08  2297.860473     182.545808
# 2     2.141929e+08  2304.495805     177.172491
# 3     2.141929e+08  2304.498259     177.296967
# 4     2.141929e+08  2304.502274     177.554158
# ..             ...          ...            ...
# 101   2.112212e+08  2321.043991     178.832485
# 102   2.127070e+08  2330.863874     189.972455
# 103   2.097354e+08  2340.567377     186.259132
# 104   2.141929e+08  2304.512653     176.817965
# 105   2.127070e+08  2312.381311     177.709105
#
# [106 rows x 3 columns]

# %%
X = loss_optimal20
Y = dislocation_optimal20
Z = func_optimal20

plotx,ploty, = np.meshgrid(np.linspace(np.min(X),np.max(X),10),\
                           np.linspace(np.min(Y),np.max(Y),10))
#plotz = interp.griddata((X,Y),Z,(plotx,ploty),method='linear')
cm = plt.cm.get_cmap('rainbow', 10)    
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111, projection='3d')
#ax.plot_wireframe(plotx,ploty,plotz)
sc = ax.scatter(X,Y,Z,c = Z, s = 30, alpha = 1, cmap =cm)
ax.set_xlabel('Economic  Loss',fontsize = 15)
ax.set_ylabel('Population Dislocation',fontsize = 15)
ax.set_zlabel('Functionality',fontsize = 15)
ax.view_init(30,210) # view the plot from different angle
fig.colorbar(sc,shrink=0.7, aspect=10)
plt.show()

# %% [markdown]
# # 40% budget

# %%
# epsilon steps
eco_range4, dislocation_range4,func_range4 = feasible_region(max_budget, 0.4)
eco_step4, dislocation_step4, func_step4 = \
            epsilon_steps(eco_range4, dislocation_range4, func_range4, 0.05)
# Out:
# Total population dislocation: 2382.1082426778526
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.59623881271403
# Total population dislocation: 2453.116140472627
# Total economic loss: 221012848.94767573
# Total housing funcnationality: 103.27725181103456

# %%
# book keeping
listLoss_fed40 = []
listStrategy_fed40_x = []
listDislocation_fed40 = []
listDislocationBlockgroup_fed40 = []
listHousingFunctionality_fed40 = []
listStrategy_fed40_y=[]
epsilon_func = []
epsilon_eco  = []
    
counter = 0
for  func_bound in np.arange(func_range4[1], func_range4[0],func_step4): # the maximum value of functionality is 1
    print ("--------iteration step", counter,"--------------")
    print("+++++++++++functionality bound", func_bound,"++++++++++")
           
    
    
    for eco_bound in np.arange(eco_range4[1], eco_range4[0], eco_step4):
        print("+++++++++++economic bound", eco_bound,"++++++++++")
        total_direct_loss, total_dislocation, strategy_x,func,strategy_y = \
                    epsilon_ecoloss_functionality(max_budget*0.4,eco_bound,func_bound)
        
        if total_dislocation !=-1:
            epsilon_func.append(func_bound)
            epsilon_eco.append(eco_bound)
        # add epsilon constraint on dislocation and total economic loss 
        # while optimizing housing functionality
        #total_direct_loss, total_dislocation, strategy_ite,dislo_blockgroup,func = \
                #epsilon_ecoloss_func(max_budget*0.5,eco_bound,func_bound)
            listLoss_fed40.append(total_direct_loss)
            listDislocation_fed40.append(total_dislocation)
            listHousingFunctionality_fed40.append(func)
            listStrategy_fed40_x.append(strategy_x)
            listStrategy_fed40_y.append(strategy_y)
        else:
            print("Infeasible")
    counter += 1
df_optimal_fed40 = pd.DataFrame({"Economic_bound":epsilon_eco,
                               "Functionality_bound": epsilon_func,
                               "Economic_loss":listLoss_fed40,
                               "Dislocation":listDislocation_fed40, 
                               "Functionality":listHousingFunctionality_fed40})
print("---------------------Overview Result-------------------")
print(df_optimal_fed40)

loss_optimal40, dislocation_optimal40,func_optimal40 = optimal_points(listLoss_fed40,listDislocation_fed40,listHousingFunctionality_fed40)
df_fed40_optimal = pd.DataFrame({
                               "Economic_loss":loss_optimal40,
                               "Dislocation":dislocation_optimal40, 
                               "Functionality":func_optimal40})
print("---------------------Overview Optimal Result-------------------")
print(df_fed40_optimal)

# Optimal results
df_fed40_optimal = pd.DataFrame({"Economic_loss":listLoss_fed40,"Dislocation":listDislocation_fed40, "Functionality":listHousingFunctionality_fed40})
df_fed40_optimal.to_csv('Results/results_B40_.csv',index = False)
# Decision variable
# Decision variable:X
for i in range(len(listStrategy_fed40_x)):
    x_i = listStrategy_fed40_x[i]
    pd_i = pd.DataFrame(list(listStrategy_fed40_x[i].iteritems()),  columns = ['Keys','Values'] )
    pd_i[['Z','S','K']] = pd.DataFrame(pd_i['Keys'].values.tolist(), columns = ['Z','S','K'])
    pd_i.to_csv("Results/decision_variable_B40_X{}.csv".format(i))
# Decision variable:Y
# Out:
# --------iteration step 0 --------------
# +++++++++++functionality bound 103.27725181103456 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 1 --------------
# +++++++++++functionality bound 106.22768565275591 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 2 --------------
# +++++++++++functionality bound 109.17811949447726 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 3 --------------
# +++++++++++functionality bound 112.1285533361986 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 4 --------------
# +++++++++++functionality bound 115.07898717791996 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 5 --------------
# +++++++++++functionality bound 118.0294210196413 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 6 --------------
# +++++++++++functionality bound 120.97985486136265 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 7 --------------
# +++++++++++functionality bound 123.930288703084 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 8 --------------
# +++++++++++functionality bound 126.88072254480535 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 9 --------------
# +++++++++++functionality bound 129.8311563865267 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 10 --------------
# +++++++++++functionality bound 132.78159022824804 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 11 --------------
# +++++++++++functionality bound 135.73202406996938 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 12 --------------
# +++++++++++functionality bound 138.68245791169073 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# ...
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 17 --------------
# +++++++++++functionality bound 153.43462712029748 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 18 --------------
# +++++++++++functionality bound 156.38506096201883 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.632866575405
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 157.92963224999494
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2274.8960891978118
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 157.75928739470206
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.1324980450154
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 157.83538016096003
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.924279597501
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 158.6881204042414
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.1432881910437
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 157.80899828397028
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2242.5757564240757
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 157.28826544364648
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.2609281526206
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 158.97499432069108
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# --------iteration step 19 --------------
# +++++++++++functionality bound 159.33549480374018 ++++++++++
# +++++++++++economic bound 183788066.83041766 ++++++++++
# Total population dislocation: 2381.55153205579
# Total economic loss: 183788066.83041766
# Total housing funcnationality: 160.79735031367773
# +++++++++++economic bound 185649305.93628058 ++++++++++
# Total population dislocation: 2294.9447237234226
# Total economic loss: 185649305.93628058
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 187510545.0421435 ++++++++++
# Total population dislocation: 2275.094710964967
# Total economic loss: 187510545.0421435
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 189371784.1480064 ++++++++++
# Total population dislocation: 2263.2533184759495
# Total economic loss: 189371784.1480064
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 191233023.25386932 ++++++++++
# Total population dislocation: 2254.9319309664947
# Total economic loss: 191233023.25386932
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 193094262.35973224 ++++++++++
# Total population dislocation: 2248.403581010602
# Total economic loss: 193094262.35973224
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 194955501.46559516 ++++++++++
# Total population dislocation: 2243.05487900387
# Total economic loss: 194955501.46559516
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 196816740.57145807 ++++++++++
# Total population dislocation: 2239.261883576308
# Total economic loss: 196816740.57145807
# Total housing funcnationality: 159.33549480374018
# +++++++++++economic bound 198677979.677321 ++++++++++
# Total population dislocation: 2236.3572546212004
# Total economic loss: 198677979.677321
# Total housing funcnationality: 159.6740337287079
# +++++++++++economic bound 200539218.7831839 ++++++++++
# Total population dislocation: 2233.825740440666
# Total economic loss: 200539218.7831839
# Total housing funcnationality: 161.64593507163335
# +++++++++++economic bound 202400457.88904682 ++++++++++
# Total population dislocation: 2231.7797977785513
# Total economic loss: 202400457.88904682
# Total housing funcnationality: 162.8997485466373
# +++++++++++economic bound 204261696.99490973 ++++++++++
# Total population dislocation: 2230.8240804843867
# Total economic loss: 204261696.99490973
# Total housing funcnationality: 162.15123658303796
# +++++++++++economic bound 206122936.10077265 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 207984175.20663556 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 209845414.31249848 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 211706653.4183614 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 213567892.5242243 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 215429131.63008723 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 217290370.73595014 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# +++++++++++economic bound 219151609.84181306 ++++++++++
# Total population dislocation: 2230.772274501107
# Total economic loss: 203966374.92326102
# Total housing funcnationality: 162.28081582708327
# ---------------------Overview Result-------------------
#      Economic_bound  Functionality_bound  Economic_loss  Dislocation  \
# 0      1.837881e+08           103.277252   1.837881e+08  2381.551532
# 1      1.856493e+08           103.277252   1.856493e+08  2294.632867
# 2      1.875105e+08           103.277252   1.875105e+08  2274.896089
# 3      1.893718e+08           103.277252   1.893718e+08  2263.132498
# 4      1.912330e+08           103.277252   1.912330e+08  2254.924280
# ..              ...                  ...            ...          ...
# 395    2.117067e+08           159.335495   2.039664e+08  2230.772275
# 396    2.135679e+08           159.335495   2.039664e+08  2230.772275
# 397    2.154291e+08           159.335495   2.039664e+08  2230.772275
# 398    2.172904e+08           159.335495   2.039664e+08  2230.772275
# 399    2.191516e+08           159.335495   2.039664e+08  2230.772275
#
#      Functionality
# 0       160.797350
# 1       157.929632
# 2       157.759287
# 3       157.835380
# 4       158.688120
# ..             ...
# 395     162.280816
# 396     162.280816
# 397     162.280816
# 398     162.280816
# 399     162.280816
#
# [400 rows x 5 columns]
# ---------------------Overview Optimal Result-------------------
#     Economic_loss  Dislocation  Functionality
# 0    2.039664e+08  2230.772275     162.280816
# 1    1.912330e+08  2254.931931     159.335495
# 2    1.875105e+08  2274.896089     157.759287
# 3    1.949555e+08  2242.575756     157.288265
# 4    2.024005e+08  2231.779798     162.899749
# 5    1.968167e+08  2239.260928     158.974994
# 6    1.837881e+08  2381.551532     160.797350
# 7    1.893718e+08  2263.253318     159.335495
# 8    1.968167e+08  2239.261884     159.335495
# 9    1.893718e+08  2263.132498     157.835380
# 10   1.856493e+08  2294.632867     157.929632
# 11   1.930943e+08  2248.143288     157.808998
# 12   1.986780e+08  2236.357255     159.674034
# 13   1.856493e+08  2294.944724     159.335495
# 14   2.005392e+08  2233.825740     161.645935
# 15   1.930943e+08  2248.403581     159.335495
# 16   1.912330e+08  2254.924280     158.688120
# 17   1.875105e+08  2275.094711     159.335495
# 18   2.042617e+08  2230.824080     162.151237
# 19   1.949555e+08  2243.054879     159.335495

# %%
X2 = loss_optimal40
Y2 = dislocation_optimal40
Z2 = func_optimal40

plotx4,ploty4, = np.meshgrid(np.linspace(np.min(X2),np.max(X2),10),\
                           np.linspace(np.min(Y2),np.max(Y2),10))
plotz4 = interp.griddata((X2,Y2),Z2,(plotx4,ploty4),method='linear')
cm = plt.cm.get_cmap('rainbow', 10)    
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111, projection='3d')
#ax.plot_wireframe(plotx,ploty,plotz)
sc = ax.scatter(X2,Y2,Z2,c = Z2, s = 30, alpha = 1, cmap =cm)
ax.set_xlabel('Economic  Loss',fontsize = 15)
ax.set_ylabel('Population Dislocation',fontsize = 15)
ax.set_zlabel('Average Repair Time in Days',fontsize = 15)
ax.view_init(30,210) # view the plot from different angle
fig.colorbar(sc,shrink=0.7, aspect=10)
plt.show()

# %% [markdown]
# ### 60% budget level

# %%
# epsilon steps
eco_range6, dislocation_range6,func_range6 = feasible_region(max_budget, 0.6)
eco_step6, dislocation_step6, func_step6 = \
            epsilon_steps(eco_range6, dislocation_range6, func_range6, 0.05)
# Out:
# Total population dislocation: 2339.16773652762
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.92503504172737
# Total population dislocation: 2356.687586449452
# Total economic loss: 202204120.21568483
# Total housing funcnationality: 94.0905396986657

# %%
# book keeping
listLoss_fed60 = []
listStrategy_fed60_x = []
listDislocation_fed60 = []
listDislocationBlockgroup_fed60 = []
listHousingFunctionality_fed60 = []
listStrategy_fed60_y=[]
epsilon_func = []
epsilon_eco  = []
    
counter = 0
for  func_bound in np.arange(func_range6[1], func_range6[0],func_step6): # the maximum value of functionality is 1
    print ("--------iteration step", counter,"--------------")
    print("+++++++++++functionality bound", func_bound,"++++++++++")
           
    
    
    for eco_bound in np.arange(eco_range6[1], eco_range6[0], eco_step6):
        print("+++++++++++economic bound", eco_bound,"++++++++++")
        total_direct_loss, total_dislocation, strategy_x,func,strategy_y = \
                    epsilon_ecoloss_functionality(max_budget*0.6,eco_bound,func_bound)
        
        if total_dislocation !=-1:
            epsilon_func.append(func_bound)
            epsilon_eco.append(eco_bound)
        # add epsilon constraint on dislocation and total economic loss 
        # while optimizing housing functionality
        #total_direct_loss, total_dislocation, strategy_ite,dislo_blockgroup,func = \
                #epsilon_ecoloss_func(max_budget*0.5,eco_bound,func_bound)
            listLoss_fed60.append(total_direct_loss)
            listDislocation_fed60.append(total_dislocation)
            listHousingFunctionality_fed60.append(func)
            listStrategy_fed60_x.append(strategy_x)
            listStrategy_fed60_y.append(strategy_y)
        else:
            print("Infeasible")
    counter += 1
df_fed60 = pd.DataFrame({"Economic_bound":epsilon_eco,
                               "Functionality_bound": epsilon_func,
                               "Economic_loss":listLoss_fed60,
                               "Dislocation":listDislocation_fed60, 
                               "Functionality":listHousingFunctionality_fed60})
print("---------------------Overview Result-------------------")
print(df_fed60)

loss_optimal60, dislocation_optimal60,func_optimal60 = optimal_points(listLoss_fed60,listDislocation_fed60,listHousingFunctionality_fed60)
df_fed60_optimal = pd.DataFrame({
                               "Economic_loss":loss_optimal60,
                               "Dislocation":dislocation_optimal60, 
                               "Functionality":func_optimal60})
print("---------------------Overview Optimal Result-------------------")
print(df_fed60_optimal)

# Optimal results
df_fed60_optimal = pd.DataFrame({"Economic_loss":listLoss_fed60,"Dislocation":listDislocation_fed60, "Functionality":listHousingFunctionality_fed60})
df_fed60_optimal.to_csv('Results/results_B60_.csv',index = False)
# Decision variable
# Decision variable:X
for i in range(len(listStrategy_fed60_x)):
    x_i = listStrategy_fed60_x[i]
    pd_i = pd.DataFrame(list(listStrategy_fed60_x[i].iteritems()),  columns = ['Keys','Values'] )
    pd_i[['Z','S','K']] = pd.DataFrame(pd_i['Keys'].values.tolist(), columns = ['Z','S','K'])
    pd_i.to_csv("Results/decision_variable_B60_X{}.csv".format(i))
# Out:
# --------iteration step 0 --------------
# +++++++++++functionality bound 94.0905396986657 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 1 --------------
# +++++++++++functionality bound 97.38170697373731 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 2 --------------
# +++++++++++functionality bound 100.67287424880892 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 3 --------------
# +++++++++++functionality bound 103.96404152388054 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 4 --------------
# +++++++++++functionality bound 107.25520879895215 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 5 --------------
# +++++++++++functionality bound 110.54637607402377 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 6 --------------
# +++++++++++functionality bound 113.83754334909538 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 7 --------------
# +++++++++++functionality bound 117.128710624167 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 8 --------------
# +++++++++++functionality bound 120.41987789923861 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.4365776879617
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.3859715152784
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 9 --------------
# +++++++++++functionality bound 123.71104517431023 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.436752905619
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.42230974800776
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 10 --------------
# +++++++++++functionality bound 127.00221244938184 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.436752905619
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.42230974800776
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 11 --------------
# +++++++++++functionality bound 130.29337972445347 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2254.436752905619
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 136.42230974800776
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2239.5527686787727
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 137.26813292884503
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2231.9157211664374
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 138.9119915020046
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2227.6722266215215
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 142.3060097001465
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2224.9313393711086
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 144.1842394401414
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.358637210674
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 145.73266906946483
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 12 --------------
# +++++++++++functionality bound 133.58454699952506 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Total population dislocation: 2339.167736518682
# Total economic loss: 168254093.39884982
# Total housing funcnationality: 140.96761283188923
# ...
# Total housing funcnationality: 146.74921609981152
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.4999529390398
# Total economic loss: 180136602.784742
# Total housing funcnationality: 147.29689466399938
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 17 --------------
# +++++++++++functionality bound 150.04038337488316 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Gurobi status is 4
# Infeasible
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2278.692369796788
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2254.6245080813414
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2240.4593944964204
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2231.769702871037
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2226.696164315599
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2223.7547884756577
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2222.55589031411
# Total economic loss: 180136602.784742
# Total housing funcnationality: 150.04038337488316
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.197342616797
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 150.1794927062398
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.138139982943
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.3907862641192
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 18 --------------
# +++++++++++functionality bound 153.33155064995475 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Gurobi status is 4
# Infeasible
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2292.5637624309575
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2263.920527755706
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2248.0967553971955
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2237.6413697467974
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2230.464697163302
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2225.9789635118614
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2223.2925422012395
# Total economic loss: 180136602.784742
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2222.2668828786614
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 153.33155064995475
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.139012701638
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 153.40208436374158
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103306416236
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 155.46203222941574
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# --------iteration step 19 --------------
# +++++++++++functionality bound 156.6227179250264 ++++++++++
# +++++++++++economic bound 168254093.39884982 ++++++++++
# Gurobi status is 4
# Infeasible
# +++++++++++economic bound 169951594.73969156 ++++++++++
# Total population dislocation: 2311.0171877332923
# Total economic loss: 169951594.73969156
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 171649096.0805333 ++++++++++
# Total population dislocation: 2276.4553499072467
# Total economic loss: 171649096.0805333
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 173346597.42137504 ++++++++++
# Total population dislocation: 2257.915312936881
# Total economic loss: 173346597.42137504
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 175044098.76221678 ++++++++++
# Total population dislocation: 2245.991432907273
# Total economic loss: 175044098.76221678
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 176741600.10305852 ++++++++++
# Total population dislocation: 2237.432966835802
# Total economic loss: 176741600.10305852
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 178439101.44390026 ++++++++++
# Total population dislocation: 2231.5243533553135
# Total economic loss: 178439101.44390026
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 180136602.784742 ++++++++++
# Total population dislocation: 2227.1515620709115
# Total economic loss: 180136602.784742
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 181834104.12558374 ++++++++++
# Total population dislocation: 2224.110586116554
# Total economic loss: 181834104.12558374
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 183531605.46642548 ++++++++++
# Total population dislocation: 2222.4458081477014
# Total economic loss: 183531605.46642548
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 185229106.80726722 ++++++++++
# Total population dislocation: 2222.103732119563
# Total economic loss: 185229106.80726722
# Total housing funcnationality: 156.6227179250264
# +++++++++++economic bound 186926608.14810896 ++++++++++
# Total population dislocation: 2222.10171132148
# Total economic loss: 186926608.14810896
# Total housing funcnationality: 156.8956448347961
# +++++++++++economic bound 188624109.4889507 ++++++++++
# Total population dislocation: 2222.10134794655
# Total economic loss: 188624109.4889507
# Total housing funcnationality: 158.54169345152584
# +++++++++++economic bound 190321610.82979244 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 190321610.82979244
# Total housing funcnationality: 159.28934200616925
# +++++++++++economic bound 192019112.17063418 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 192019112.17063418
# Total housing funcnationality: 159.4834514083699
# +++++++++++economic bound 193716613.51147592 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 193716613.51147592
# Total housing funcnationality: 159.60719192485908
# +++++++++++economic bound 195414114.85231766 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 195414114.85231766
# Total housing funcnationality: 159.85413625390055
# +++++++++++economic bound 197111616.1931594 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 197111616.1931594
# Total housing funcnationality: 159.894171232975
# +++++++++++economic bound 198809117.53400114 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# +++++++++++economic bound 200506618.87484288 ++++++++++
# Total population dislocation: 2222.1013205054896
# Total economic loss: 198420148.73684478
# Total housing funcnationality: 159.91388520009846
# ---------------------Overview Result-------------------
#      Economic_bound  Functionality_bound  Economic_loss  Dislocation  \
# 0      1.682541e+08            94.090540   1.682541e+08  2339.167737
# 1      1.699516e+08            94.090540   1.699516e+08  2254.436578
# 2      1.716491e+08            94.090540   1.716491e+08  2239.552769
# 3      1.733466e+08            94.090540   1.733466e+08  2231.915721
# 4      1.750441e+08            94.090540   1.750441e+08  2227.672227
# ..              ...                  ...            ...          ...
# 390    1.937166e+08           156.622718   1.937166e+08  2222.101321
# 391    1.954141e+08           156.622718   1.954141e+08  2222.101321
# 392    1.971116e+08           156.622718   1.971116e+08  2222.101321
# 393    1.988091e+08           156.622718   1.984201e+08  2222.101321
# 394    2.005066e+08           156.622718   1.984201e+08  2222.101321
#
#      Functionality
# 0       140.967613
# 1       136.385972
# 2       137.268133
# 3       138.911992
# 4       142.306010
# ..             ...
# 390     159.607192
# 391     159.854136
# 392     159.894171
# 393     159.913885
# 394     159.913885
#
# [395 rows x 5 columns]
# ---------------------Overview Optimal Result-------------------
#     Economic_loss  Dislocation  Functionality
# 0    1.869266e+08  2222.101711     156.895645
# 1    1.682541e+08  2339.167737     140.967613
# 2    1.682541e+08  2339.167737     140.966762
# 3    1.767416e+08  2225.200765     146.749216
# 4    1.733466e+08  2232.678076     143.458049
# ..            ...          ...            ...
# 58   1.801366e+08  2222.555890     150.040383
# 59   1.767416e+08  2237.432967     156.622718
# 60   1.716491e+08  2263.920528     153.331551
# 61   1.682541e+08  2339.167737     141.001442
# 62   1.767416e+08  2230.464697     153.331551
#
# [63 rows x 3 columns]

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(15,7))
sc1 = ax.scatter(loss_optimal60,dislocation_optimal60,c=func_optimal60,cmap =plt.cm.get_cmap('Blues', 10))
fig.colorbar(sc1,shrink=0.5, aspect=7,label = 'Avg Repair Time with $40M budget')
#legend1 = ax.legend(*sc1.legend_elements(),loc="upper right")
#ax.add_artist(legend1)

sc2 = ax.scatter(loss_optimal40,dislocation_optimal40,c=func_optimal40,cmap =plt.cm.get_cmap('Greens', 10))
fig.colorbar(sc2,shrink=0.5, aspect=7,label = "Avg Repair Time with $80M budget")
#legend2 = ax.legend(*sc2.legend_elements(),loc="lower right")
#ax.add_artist(legend2)

sc3 = ax.scatter(loss_optimal20,dislocation_optimal20,c=func_optimal20,cmap =plt.cm.get_cmap('Reds', 10))
#v3 = np.linspace(min(loss_optimal20), max(loss_optimal20), 10, endpoint=True)
fig.colorbar(sc3,shrink=0.5, aspect=7,label = "Avg Repair Time with $120M budget")
#legend3 = ax.legend(*sc3.legend_elements(),loc="lower left")
#ax.add_artist(legend3)

ax.set_xlabel("Economic Loss $",fontsize = 15)
ax.set_ylabel("Population Dislocation",fontsize = 15)
ax.set_title("Pareto frontier: Economic Loss in $ vs. Dislocation of different budgets ",fontsize = 15)
fig.tight_layout()

plt.grid()
Budget_20 = mpatches.Patch(color='red', label='$40M budget')
Budget_40 = mpatches.Patch(color='green', label='$80M budget')
Budget_60 = mpatches.Patch(color='steelblue', label='$120M budget')

p1 = plt.scatter(203792010.051994,2527.92468004801,color = 'red',s = 150,marker ='h',alpha=0.6)
p2 = plt.scatter(216614004.631429,2295.65009504016,color = 'cyan',s = 200,marker ='s',alpha=0.6)
p3 = plt.scatter(214192863.928346,2304.51265325845,color = 'purple',s = 150,marker ='D',alpha=0.6)
p1 = plt.scatter(183788066.830417,2381.55153205579,color = 'red',s = 150,marker ='h',alpha=0.6)
p2 = plt.scatter(203966374.923261,2230.7722745011,color = 'cyan',s = 200,marker ='s',alpha=0.6)
p3 = plt.scatter(194955501.465595,2242.57575642407,color = 'purple',s = 150,marker ='D',alpha=0.6)
p1 = plt.scatter(168254093.398849,2339.16773651868,color = 'red',s = 150,marker ='h',alpha=0.6)
p2 = plt.scatter(190321610.829792,2222.10132050548,color = 'cyan',s = 200,marker ='s',alpha=0.6)
p3 = plt.scatter(169951594.739691,2254.43629028356,color = 'purple',s = 150,marker ='D',alpha=0.6)

# Create the second legend and add the artist manually.
from matplotlib.legend import Legend
leg = plt.legend((p1,p2,p3),('Plan 1','Plan 2', 'Plan 3'),loc="upper left",fontsize = 15)
ax.add_artist(leg);
plt.legend(handles=[Budget_20,Budget_40,Budget_60])

# %%
X6 = loss_optimal60
Y6 = dislocation_optimal60
Z6 = func_optimal60
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X,Y,Z,c= Z,cmap=plt.cm.get_cmap('Reds'))
ax.scatter(X2,Y2,Z2,c= Z2,cmap=plt.cm.get_cmap('Greens'))
ax.scatter(X6,Y6,Z6,c= Z6,cmap=plt.cm.get_cmap('Blues'))
#ax.contour3D(plotx,ploty,plotz,100,cmap=plt.cm.get_cmap('Reds', 10))
#ax.contour3D(plotx4,ploty4,plotz4,100,cmap=plt.cm.get_cmap('Greens', 10))
#ax.contour3D(plotx6,ploty6,plotz6, 100,cmap=plt.cm.get_cmap('Blues', 10))
#ax.plot_surface(plotx,ploty,plotz,color = 'blue')
#ax.plot_surface(plotx4,ploty4,plotz4,color = 'orange')
#ax.plot_surface(plotx6,ploty6,plotz6,color = 'green')
ax.set_xlabel('Economic Loss',fontsize = 12)
ax.set_ylabel('Population Dislocation',fontsize = 12)
ax.set_zlabel('Functionality',fontsize = 12)
Budget_20 = mpatches.Patch(color='red', label='20% budget')
Budget_40 = mpatches.Patch(color='green', label='40% budget')
Budget_60 = mpatches.Patch(color='steelblue', label='60% budget')
plt.legend(handles=[Budget_20,Budget_40,Budget_60])
ax.view_init(30,60) # view the plot from different angle
plt.show()
